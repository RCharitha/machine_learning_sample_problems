# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.DataFrame({'height':[60,62,64	,66	,68	,70	,72	,74	,76	,78],
                'age':[25,30,35,40,45,50,55,60,65,70],
                'gender':['f','f','m','m','f','m','m','f','m','m'],
                'weights':[110,120,130,140,150,160,170,180,190,200]})

# %%
df.head()
# Out:
#    height  age gender  weights
# 0      60   25      f      110
# 1      62   30      f      120
# 2      64   35      m      130
# 3      66   40      m      140
# 4      68   45      f      150

# %%
df['gender']=df['gender'].map({'f':0,'m':1})

# %%
df.head()
# Out:
#    height  age  gender  weights
# 0      60   25       0      110
# 1      62   30       0      120
# 2      64   35       1      130
# 3      66   40       1      140
# 4      68   45       0      150

# %%
model=LinearRegression()
x=df.drop('weights',axis='columns')
y=df['weights']

# %%
x
# Out:
#    height  age  gender
# 0      60   25       0
# 1      62   30       0
# 2      64   35       1
# 3      66   40       1
# 4      68   45       0
# 5      70   50       1
# 6      72   55       1
# 7      74   60       0
# 8      76   65       1
# 9      78   70       1

# %%
#x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8)

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[62	,30	,0]])
# Out:
# C:\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([120.])

# %%
model.predict([[5.4,20,0]])
# Out:
# C:\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([63.72413793])

# %%
model.predict([[5.2,19,0]])
# Out:
# C:\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([61.86206897])
